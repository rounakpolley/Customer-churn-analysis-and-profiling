# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
df1 = pd.read_pickle("./ds1_trans.pkl")
df2 = pd.read_pickle("./ds2_trans.pkl")

# %% [markdown]
# So both the datasets have sufficient number of +ve i.e. intances where churn has occured
# ### Now splitting the datasets

# %%
def split_datasets(df):
    df_train = df[0:0]
    df_test  = df[0:0]
    for index, row in df.iterrows():
        if float(random.random()) < 0.8 :
            df_train.loc[len(df_train)] = row
        else :
            df_test.loc[len(df_test)] = row
    return df_train, df_test

# %%
df1_train, df1_test = split_datasets(df1)
df2_train, df2_test = split_datasets(df2)
print("The test set to original data ratio")
print("1st dataset :" + str(len(df1_train)/(len(df1_train)+len(df1_test))))
print("2nd dataset :" + str(len(df2_train)/(len(df2_train)+len(df2_test))))
# Out:
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# The test set to original data ratio
# 1st dataset :0.7932793279327933
# 2nd dataset :0.7983193277310925

# %%
df1_train.to_pickle("./df1_train.pkl")
df1_test.to_pickle("./df1_test.pkl")

df2_train.to_pickle("./df2_train.pkl")
df2_test.to_pickle("./df2_test.pkl")

# %%
def plot_churn(tmp_df1, tmp_df2):
    colors = ['r', 'g']
    
    l1 = tmp_df1.churn.value_counts().keys().tolist()
    v1 = tmp_df1.churn.value_counts().tolist()

    l2 = tmp_df2.Churn.value_counts().keys().tolist()
    v2 = tmp_df2.Churn.value_counts().tolist()

    plt.subplot(1, 2, 1)
    plt.title('Dataset 1')
    plt.pie(v1, labels=l1, colors=colors, startangle=90, autopct='%.1f%%')
    plt.axis("equal")
    plt.xlabel(str(len(tmp_df1))+" no. of data items")

    plt.subplot(1, 2, 2)
    plt.title('Dataset 2')
    plt.pie(v2, labels=l2, colors=colors, startangle=90, autopct='%.1f%%')
    plt.axis("equal")
    plt.xlabel(str(len(tmp_df2))+" no. of data items")

    plt.show()
    return

print("=== Original datasets ===")
plot_churn(df1, df2)
print("=== Training Sets ===")
plot_churn(df1_train, df2_train)
print("=== Test sets ===")
plot_churn(df1_test, df2_test)
# Out:
# === Original datasets ===
# === Training Sets ===
# === Test sets ===

# %% [markdown]
# ### Hence both the datasets are split in 8:2 (train:test) ratio while retaining the ratio of churn to non-churn

# %% [markdown]
# ### Now splitting datasets into churn and not churn

# %%
df1_churn     = df1[df1['churn'] == 1]
df2_churn     = df2[df2['Churn'] == 1.0]
df1_not_churn = df1[df1['churn'] == 0]
df2_not_churn = df2[df2['Churn'] == 0.0]

print(str(len(df1_churn))+" "+str(len(df1_not_churn))+" || "+str(len(df2_churn))+" "+str(len(df2_not_churn)))
# Out:
# 483 2850 || 1857 5164

# %%
df1_churn.to_pickle("./df1_churn.pkl")
df2_churn.to_pickle("./df2_churn.pkl")

df1_not_churn.to_pickle("./df1_not_churn.pkl")
df2_not_churn.to_pickle("./df2_not_churn.pkl")
