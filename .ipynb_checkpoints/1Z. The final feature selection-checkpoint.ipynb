# %%
import pandas as pd
import numpy as np
from collections import Counter
from itertools import combinations

from sklearn.linear_model import LogisticRegression

from sklearn import metrics
from sklearn.preprocessing import StandardScaler

df1_train = pd.read_pickle("./df1_reduced_train.pkl")
df1_test  = pd.read_pickle("./df1_reduced_test.pkl")

print(str(len(df1_train))+" "+str(len(df1_test)))
# Out:
# 2661 672

# %%
def get_data(col_names):    #col_names : list
    col_names     = col_names + ['churn']
    df_train      = df1_train[col_names]
    df_test       = df1_test[col_names]
    X_train       = df1_train.iloc[:,:-1]
    y_train       = df1_train.iloc[:,-1:]
    X_test        = df1_test.iloc[:,:-1]
    y_test        = df1_test.iloc[:,-1:]
    
    scaler        = StandardScaler()
    scaler.fit(X_train)                                       
    X_train       = scaler.transform(X_train)
    X_test        = scaler.transform(X_test)
    
    return X_train, y_train, X_test, y_test

# %%
for i in range(2,14):
    max_accuracy = 0
    selected_col = []
    print("********************************************           ",str(i))
    col_comb = list(combinations(df1_train.columns[:-1], i))
    for j in range(len(col_comb)):
        col_names      = list(col_comb[j])
        print(col_names)
        ij_X_train, ij_y_train, ij_X_test, ij_y_test = get_data(col_names)
        print(ij_X_train.shape)
        logreg         = LogisticRegression().fit(ij_X_train,ij_y_train)
        ij_y_pred_test = logreg.predict(ij_X_test)
        accuracy       = metrics.accuracy_score(ij_y_test, ij_y_pred_test)
        if(accuracy > max_accuracy):
            max_accuracy = accuracy
            selected_col = col_names
            print(max_accuracy)
            print(selected_col)
# Out:
# ********************************************            2
# ['account length', 'area code']
# (2661, 13)
# 0.861607142857
# ['account length', 'area code']
# ['account length', 'international plan']
# (2661, 13)
# ['account length', 'number vmail messages']
# (2661, 13)
# ['account length', 'total day calls']
# (2661, 13)
# ['account length', 'total day charge']
# (2661, 13)
# ['account length', 'total eve calls']
# (2661, 13)
# ['account length', 'total eve charge']
# (2661, 13)
# ['account length', 'total night calls']
# (2661, 13)
# ['account length', 'total night charge']
# (2661, 13)
# ['account length', 'total intl calls']
# (2661, 13)
# ['account length', 'total intl charge']
# (2661, 13)
# ['account length', 'customer service calls']
# (2661, 13)
# ['area code', 'international plan']
# (2661, 13)
# ['area code', 'number vmail messages']
# (2661, 13)
# ['area code', 'total day calls']
# (2661, 13)
# ['area code', 'total day charge']
# (2661, 13)
# ['area code', 'total eve calls']
# (2661, 13)
# ['area code', 'total eve charge']
# (2661, 13)
# ['area code', 'total night calls']
# (2661, 13)
# ['area code', 'total night charge']
# F:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:547: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# (2661, 13)
# ['area code', 'total intl calls']
# (2661, 13)
# ['area code', 'total intl charge']
# (2661, 13)
# ['area code', 'customer service calls']
# (2661, 13)
# ['international plan', 'number vmail messages']
# (2661, 13)
# ['international plan', 'total day calls']
# (2661, 13)
# ['international plan', 'total day charge']
# (2661, 13)
# ['international plan', 'total eve calls']
# (2661, 13)
# ['international plan', 'total eve charge']
# (2661, 13)
# ['international plan', 'total night calls']
# (2661, 13)
# ['international plan', 'total night charge']
# (2661, 13)
# ['international plan', 'total intl calls']
# (2661, 13)
# ['international plan', 'total intl charge']
# (2661, 13)
# ['international plan', 'customer service calls']
# (2661, 13)
# ['number vmail messages', 'total day calls']
# (2661, 13)
# ['number vmail messages', 'total day charge']
# (2661, 13)
# ['number vmail messages', 'total eve calls']
# (2661, 13)
# ['number vmail messages', 'total eve charge']
# (2661, 13)
# ['number vmail messages', 'total night calls']
# (2661, 13)
# ['number vmail messages', 'total night charge']
# (2661, 13)
# ['number vmail messages', 'total intl calls']
# (2661, 13)
# ['number vmail messages', 'total intl charge']
# (2661, 13)
# ['number vmail messages', 'customer service calls']
# (2661, 13)
# ['total day calls', 'total day charge']
# (2661, 13)
# ['total day calls', 'total eve calls']
# (2661, 13)
# ['total day calls', 'total eve charge']
# (2661, 13)
# ['total day calls', 'total night calls']
# (2661, 13)
# ['total day calls', 'total night charge']
# (2661, 13)
# ['total day calls', 'total intl calls']
# (2661, 13)
# ['total day calls', 'total intl charge']
# (2661, 13)
# ['total day calls', 'customer service calls']
# (2661, 13)
# ['total day charge', 'total eve calls']
# (2661, 13)
# ['total day charge', 'total eve charge']
# (2661, 13)
# ['total day charge', 'total night calls']
# (2661, 13)
# ['total day charge', 'total night charge']
# (2661, 13)
# ['total day charge', 'total intl calls']
# (2661, 13)
# ['total day charge', 'total intl charge']
# (2661, 13)
# ['total day charge', 'customer service calls']
# (2661, 13)
# ['total eve calls', 'total eve charge']
# (2661, 13)
# ['total eve calls', 'total night calls']
# (2661, 13)
# ['total eve calls', 'total night charge']
# (2661, 13)
# ['total eve calls', 'total intl calls']
# (2661, 13)
# ['total eve calls', 'total intl charge']
# (2661, 13)
# ['total eve calls', 'customer service calls']
# (2661, 13)
# ['total eve charge', 'total night calls']
# (2661, 13)
# ['total eve charge', 'total night charge']
# (2661, 13)
# ['total eve charge', 'total intl calls']
# (2661, 13)
# ['total eve charge', 'total intl charge']
# (2661, 13)
# ['total eve charge', 'customer service calls']
# (2661, 13)
# ['total night calls', 'total night charge']
# (2661, 13)
# ['total night calls', 'total intl calls']
# (2661, 13)
# ['total night calls', 'total intl charge']
# (2661, 13)
# ['total night calls', 'customer service calls']
# (2661, 13)
# ['total night charge', 'total intl calls']
# (2661, 13)
# ['total night charge', 'total intl charge']
# (2661, 13)
# ['total night charge', 'customer service calls']
# (2661, 13)
# ['total intl calls', 'total intl charge']
# (2661, 13)
# ['total intl calls', 'customer service calls']
# (2661, 13)
# ['total intl charge', 'customer service calls']
# (2661, 13)
# ********************************************            3
# ['account length', 'area code', 'international plan']
# (2661, 13)
# 0.861607142857
# ['account length', 'area code', 'international plan']
# ['account length', 'area code', 'number vmail messages']
# (2661, 13)
# ['account length', 'area code', 'total day calls']
# (2661, 13)
# ['account length', 'area code', 'total day charge']
# (2661, 13)
# ['account length', 'area code', 'total eve calls']
# (2661, 13)
# ['account length', 'area code', 'total eve charge']
# (2661, 13)
# ['account length', 'area code', 'total night calls']
# (2661, 13)
# ['account length', 'area code', 'total night charge']
# (2661, 13)
# ['account length', 'area code', 'total intl calls']
# (2661, 13)
# ['account length', 'area code', 'total intl charge']
# (2661, 13)
# ['account length', 'area code', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'number vmail messages']
# (2661, 13)
# ['account length', 'international plan', 'total day calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve charge']
# (2661, 13)
# ['account length', 'international plan', 'total night calls']
# (2661, 13)
# ['account length', 'international plan', 'total night charge']
# (2661, 13)
# ['account length', 'international plan', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'customer service calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total eve calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total eve charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total night calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total night charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total intl calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total intl charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'customer service calls']
# (2661, 13)
# ['account length', 'total day calls', 'total day charge']
# (2661, 13)
# ['account length', 'total day calls', 'total eve calls']
# (2661, 13)
# ['account length', 'total day calls', 'total eve charge']
# (2661, 13)
# ['account length', 'total day calls', 'total night calls']
# (2661, 13)
# ['account length', 'total day calls', 'total night charge']
# (2661, 13)
# ['account length', 'total day calls', 'total intl calls']
# (2661, 13)
# ['account length', 'total day calls', 'total intl charge']
# (2661, 13)
# ['account length', 'total day calls', 'customer service calls']
# (2661, 13)
# ['account length', 'total day charge', 'total eve calls']
# (2661, 13)
# ['account length', 'total day charge', 'total eve charge']
# (2661, 13)
# ['account length', 'total day charge', 'total night calls']
# (2661, 13)
# ['account length', 'total day charge', 'total night charge']
# (2661, 13)
# ['account length', 'total day charge', 'total intl calls']
# (2661, 13)
# ['account length', 'total day charge', 'total intl charge']
# (2661, 13)
# ['account length', 'total day charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total eve calls', 'total eve charge']
# (2661, 13)
# ['account length', 'total eve calls', 'total night calls']
# (2661, 13)
# ['account length', 'total eve calls', 'total night charge']
# (2661, 13)
# ['account length', 'total eve calls', 'total intl calls']
# (2661, 13)
# ['account length', 'total eve calls', 'total intl charge']
# (2661, 13)
# ['account length', 'total eve calls', 'customer service calls']
# (2661, 13)
# ['account length', 'total eve charge', 'total night calls']
# (2661, 13)
# ['account length', 'total eve charge', 'total night charge']
# (2661, 13)
# ['account length', 'total eve charge', 'total intl calls']
# (2661, 13)
# ['account length', 'total eve charge', 'total intl charge']
# (2661, 13)
# ['account length', 'total eve charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total night calls', 'total night charge']
# (2661, 13)
# ['account length', 'total night calls', 'total intl calls']
# (2661, 13)
# ['account length', 'total night calls', 'total intl charge']
# (2661, 13)
# ['account length', 'total night calls', 'customer service calls']
# (2661, 13)
# ['account length', 'total night charge', 'total intl calls']
# (2661, 13)
# ['account length', 'total night charge', 'total intl charge']
# (2661, 13)
# ['account length', 'total night charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['area code', 'international plan', 'number vmail messages']
# (2661, 13)
# ['area code', 'international plan', 'total day calls']
# (2661, 13)
# ['area code', 'international plan', 'total day charge']
# (2661, 13)
# ['area code', 'international plan', 'total eve calls']
# (2661, 13)
# ['area code', 'international plan', 'total eve charge']
# (2661, 13)
# ['area code', 'international plan', 'total night calls']
# (2661, 13)
# ['area code', 'international plan', 'total night charge']
# (2661, 13)
# ['area code', 'international plan', 'total intl calls']
# (2661, 13)
# ['area code', 'international plan', 'total intl charge']
# (2661, 13)
# ['area code', 'international plan', 'customer service calls']
# (2661, 13)
# ['area code', 'number vmail messages', 'total day calls']
# (2661, 13)
# ['area code', 'number vmail messages', 'total day charge']
# (2661, 13)
# ['area code', 'number vmail messages', 'total eve calls']
# (2661, 13)
# ['area code', 'number vmail messages', 'total eve charge']
# (2661, 13)
# ['area code', 'number vmail messages', 'total night calls']
# (2661, 13)
# ['area code', 'number vmail messages', 'total night charge']
# (2661, 13)
# ['area code', 'number vmail messages', 'total intl calls']
# (2661, 13)
# ['area code', 'number vmail messages', 'total intl charge']
# (2661, 13)
# ['area code', 'number vmail messages', 'customer service calls']
# (2661, 13)
# ['area code', 'total day calls', 'total day charge']
# (2661, 13)
# ['area code', 'total day calls', 'total eve calls']
# (2661, 13)
# ['area code', 'total day calls', 'total eve charge']
# (2661, 13)
# ['area code', 'total day calls', 'total night calls']
# (2661, 13)
# ['area code', 'total day calls', 'total night charge']
# (2661, 13)
# ['area code', 'total day calls', 'total intl calls']
# (2661, 13)
# ['area code', 'total day calls', 'total intl charge']
# (2661, 13)
# ['area code', 'total day calls', 'customer service calls']
# (2661, 13)
# ['area code', 'total day charge', 'total eve calls']
# (2661, 13)
# ['area code', 'total day charge', 'total eve charge']
# (2661, 13)
# ['area code', 'total day charge', 'total night calls']
# (2661, 13)
# ['area code', 'total day charge', 'total night charge']
# (2661, 13)
# ['area code', 'total day charge', 'total intl calls']
# (2661, 13)
# ['area code', 'total day charge', 'total intl charge']
# (2661, 13)
# ['area code', 'total day charge', 'customer service calls']
# (2661, 13)
# ['area code', 'total eve calls', 'total eve charge']
# (2661, 13)
# ['area code', 'total eve calls', 'total night calls']
# (2661, 13)
# ['area code', 'total eve calls', 'total night charge']
# (2661, 13)
# ['area code', 'total eve calls', 'total intl calls']
# (2661, 13)
# ['area code', 'total eve calls', 'total intl charge']
# (2661, 13)
# ['area code', 'total eve calls', 'customer service calls']
# (2661, 13)
# ['area code', 'total eve charge', 'total night calls']
# (2661, 13)
# ['area code', 'total eve charge', 'total night charge']
# (2661, 13)
# ['area code', 'total eve charge', 'total intl calls']
# (2661, 13)
# ['area code', 'total eve charge', 'total intl charge']
# (2661, 13)
# ['area code', 'total eve charge', 'customer service calls']
# (2661, 13)
# ['area code', 'total night calls', 'total night charge']
# (2661, 13)
# ['area code', 'total night calls', 'total intl calls']
# (2661, 13)
# ['area code', 'total night calls', 'total intl charge']
# (2661, 13)
# ['area code', 'total night calls', 'customer service calls']
# (2661, 13)
# ['area code', 'total night charge', 'total intl calls']
# (2661, 13)
# ['area code', 'total night charge', 'total intl charge']
# (2661, 13)
# ['area code', 'total night charge', 'customer service calls']
# (2661, 13)
# ['area code', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['area code', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['area code', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['international plan', 'number vmail messages', 'total day calls']
# (2661, 13)
# ['international plan', 'number vmail messages', 'total day charge']
# (2661, 13)
# ['international plan', 'number vmail messages', 'total eve calls']
# (2661, 13)
# ['international plan', 'number vmail messages', 'total eve charge']
# (2661, 13)
# ['international plan', 'number vmail messages', 'total night calls']
# (2661, 13)
# ['international plan', 'number vmail messages', 'total night charge']
# (2661, 13)
# ['international plan', 'number vmail messages', 'total intl calls']
# (2661, 13)
# ['international plan', 'number vmail messages', 'total intl charge']
# (2661, 13)
# ['international plan', 'number vmail messages', 'customer service calls']
# (2661, 13)
# ['international plan', 'total day calls', 'total day charge']
# (2661, 13)
# ['international plan', 'total day calls', 'total eve calls']
# (2661, 13)
# ['international plan', 'total day calls', 'total eve charge']
# (2661, 13)
# ['international plan', 'total day calls', 'total night calls']
# (2661, 13)
# ['international plan', 'total day calls', 'total night charge']
# (2661, 13)
# ['international plan', 'total day calls', 'total intl calls']
# (2661, 13)
# ['international plan', 'total day calls', 'total intl charge']
# (2661, 13)
# ['international plan', 'total day calls', 'customer service calls']
# (2661, 13)
# ['international plan', 'total day charge', 'total eve calls']
# (2661, 13)
# ['international plan', 'total day charge', 'total eve charge']
# (2661, 13)
# ['international plan', 'total day charge', 'total night calls']
# (2661, 13)
# ['international plan', 'total day charge', 'total night charge']
# (2661, 13)
# ['international plan', 'total day charge', 'total intl calls']
# (2661, 13)
# ['international plan', 'total day charge', 'total intl charge']
# (2661, 13)
# ['international plan', 'total day charge', 'customer service calls']
# (2661, 13)
# ['international plan', 'total eve calls', 'total eve charge']
# (2661, 13)
# ['international plan', 'total eve calls', 'total night calls']
# (2661, 13)
# ['international plan', 'total eve calls', 'total night charge']
# (2661, 13)
# ['international plan', 'total eve calls', 'total intl calls']
# (2661, 13)
# ['international plan', 'total eve calls', 'total intl charge']
# (2661, 13)
# ['international plan', 'total eve calls', 'customer service calls']
# (2661, 13)
# ['international plan', 'total eve charge', 'total night calls']
# (2661, 13)
# ['international plan', 'total eve charge', 'total night charge']
# (2661, 13)
# ['international plan', 'total eve charge', 'total intl calls']
# (2661, 13)
# ['international plan', 'total eve charge', 'total intl charge']
# (2661, 13)
# ['international plan', 'total eve charge', 'customer service calls']
# (2661, 13)
# ['international plan', 'total night calls', 'total night charge']
# (2661, 13)
# ['international plan', 'total night calls', 'total intl calls']
# (2661, 13)
# ['international plan', 'total night calls', 'total intl charge']
# (2661, 13)
# ['international plan', 'total night calls', 'customer service calls']
# (2661, 13)
# ['international plan', 'total night charge', 'total intl calls']
# (2661, 13)
# ['international plan', 'total night charge', 'total intl charge']
# (2661, 13)
# ['international plan', 'total night charge', 'customer service calls']
# (2661, 13)
# ['international plan', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['international plan', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['international plan', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['number vmail messages', 'total day calls', 'total day charge']
# (2661, 13)
# ['number vmail messages', 'total day calls', 'total eve calls']
# (2661, 13)
# ['number vmail messages', 'total day calls', 'total eve charge']
# (2661, 13)
# ['number vmail messages', 'total day calls', 'total night calls']
# (2661, 13)
# ['number vmail messages', 'total day calls', 'total night charge']
# (2661, 13)
# ['number vmail messages', 'total day calls', 'total intl calls']
# (2661, 13)
# ['number vmail messages', 'total day calls', 'total intl charge']
# (2661, 13)
# ['number vmail messages', 'total day calls', 'customer service calls']
# (2661, 13)
# ['number vmail messages', 'total day charge', 'total eve calls']
# (2661, 13)
# ['number vmail messages', 'total day charge', 'total eve charge']
# (2661, 13)
# ['number vmail messages', 'total day charge', 'total night calls']
# (2661, 13)
# ['number vmail messages', 'total day charge', 'total night charge']
# (2661, 13)
# ['number vmail messages', 'total day charge', 'total intl calls']
# (2661, 13)
# ['number vmail messages', 'total day charge', 'total intl charge']
# (2661, 13)
# ['number vmail messages', 'total day charge', 'customer service calls']
# (2661, 13)
# ['number vmail messages', 'total eve calls', 'total eve charge']
# (2661, 13)
# ['number vmail messages', 'total eve calls', 'total night calls']
# (2661, 13)
# ['number vmail messages', 'total eve calls', 'total night charge']
# (2661, 13)
# ['number vmail messages', 'total eve calls', 'total intl calls']
# (2661, 13)
# ['number vmail messages', 'total eve calls', 'total intl charge']
# (2661, 13)
# ['number vmail messages', 'total eve calls', 'customer service calls']
# (2661, 13)
# ['number vmail messages', 'total eve charge', 'total night calls']
# (2661, 13)
# ['number vmail messages', 'total eve charge', 'total night charge']
# (2661, 13)
# ['number vmail messages', 'total eve charge', 'total intl calls']
# (2661, 13)
# ['number vmail messages', 'total eve charge', 'total intl charge']
# (2661, 13)
# ['number vmail messages', 'total eve charge', 'customer service calls']
# (2661, 13)
# ['number vmail messages', 'total night calls', 'total night charge']
# (2661, 13)
# ['number vmail messages', 'total night calls', 'total intl calls']
# (2661, 13)
# ['number vmail messages', 'total night calls', 'total intl charge']
# (2661, 13)
# ['number vmail messages', 'total night calls', 'customer service calls']
# (2661, 13)
# ['number vmail messages', 'total night charge', 'total intl calls']
# (2661, 13)
# ['number vmail messages', 'total night charge', 'total intl charge']
# (2661, 13)
# ['number vmail messages', 'total night charge', 'customer service calls']
# (2661, 13)
# ['number vmail messages', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['number vmail messages', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['number vmail messages', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['total day calls', 'total day charge', 'total eve calls']
# (2661, 13)
# ['total day calls', 'total day charge', 'total eve charge']
# (2661, 13)
# ['total day calls', 'total day charge', 'total night calls']
# (2661, 13)
# ['total day calls', 'total day charge', 'total night charge']
# (2661, 13)
# ['total day calls', 'total day charge', 'total intl calls']
# (2661, 13)
# ['total day calls', 'total day charge', 'total intl charge']
# (2661, 13)
# ['total day calls', 'total day charge', 'customer service calls']
# (2661, 13)
# ['total day calls', 'total eve calls', 'total eve charge']
# (2661, 13)
# ['total day calls', 'total eve calls', 'total night calls']
# (2661, 13)
# ['total day calls', 'total eve calls', 'total night charge']
# (2661, 13)
# ['total day calls', 'total eve calls', 'total intl calls']
# (2661, 13)
# ['total day calls', 'total eve calls', 'total intl charge']
# (2661, 13)
# ['total day calls', 'total eve calls', 'customer service calls']
# (2661, 13)
# ['total day calls', 'total eve charge', 'total night calls']
# (2661, 13)
# ['total day calls', 'total eve charge', 'total night charge']
# (2661, 13)
# ['total day calls', 'total eve charge', 'total intl calls']
# (2661, 13)
# ['total day calls', 'total eve charge', 'total intl charge']
# (2661, 13)
# ['total day calls', 'total eve charge', 'customer service calls']
# (2661, 13)
# ['total day calls', 'total night calls', 'total night charge']
# (2661, 13)
# ['total day calls', 'total night calls', 'total intl calls']
# (2661, 13)
# ['total day calls', 'total night calls', 'total intl charge']
# (2661, 13)
# ['total day calls', 'total night calls', 'customer service calls']
# (2661, 13)
# ['total day calls', 'total night charge', 'total intl calls']
# (2661, 13)
# ['total day calls', 'total night charge', 'total intl charge']
# (2661, 13)
# ['total day calls', 'total night charge', 'customer service calls']
# (2661, 13)
# ['total day calls', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['total day calls', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['total day calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['total day charge', 'total eve calls', 'total eve charge']
# (2661, 13)
# ['total day charge', 'total eve calls', 'total night calls']
# (2661, 13)
# ['total day charge', 'total eve calls', 'total night charge']
# (2661, 13)
# ['total day charge', 'total eve calls', 'total intl calls']
# (2661, 13)
# ['total day charge', 'total eve calls', 'total intl charge']
# (2661, 13)
# ['total day charge', 'total eve calls', 'customer service calls']
# (2661, 13)
# ['total day charge', 'total eve charge', 'total night calls']
# (2661, 13)
# ['total day charge', 'total eve charge', 'total night charge']
# (2661, 13)
# ['total day charge', 'total eve charge', 'total intl calls']
# (2661, 13)
# ['total day charge', 'total eve charge', 'total intl charge']
# (2661, 13)
# ['total day charge', 'total eve charge', 'customer service calls']
# (2661, 13)
# ['total day charge', 'total night calls', 'total night charge']
# (2661, 13)
# ['total day charge', 'total night calls', 'total intl calls']
# (2661, 13)
# ['total day charge', 'total night calls', 'total intl charge']
# (2661, 13)
# ['total day charge', 'total night calls', 'customer service calls']
# (2661, 13)
# ['total day charge', 'total night charge', 'total intl calls']
# (2661, 13)
# ['total day charge', 'total night charge', 'total intl charge']
# (2661, 13)
# ['total day charge', 'total night charge', 'customer service calls']
# (2661, 13)
# ['total day charge', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['total day charge', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['total day charge', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['total eve calls', 'total eve charge', 'total night calls']
# (2661, 13)
# ['total eve calls', 'total eve charge', 'total night charge']
# (2661, 13)
# ['total eve calls', 'total eve charge', 'total intl calls']
# (2661, 13)
# ['total eve calls', 'total eve charge', 'total intl charge']
# (2661, 13)
# ['total eve calls', 'total eve charge', 'customer service calls']
# (2661, 13)
# ['total eve calls', 'total night calls', 'total night charge']
# (2661, 13)
# ['total eve calls', 'total night calls', 'total intl calls']
# (2661, 13)
# ['total eve calls', 'total night calls', 'total intl charge']
# (2661, 13)
# ['total eve calls', 'total night calls', 'customer service calls']
# (2661, 13)
# ['total eve calls', 'total night charge', 'total intl calls']
# (2661, 13)
# ['total eve calls', 'total night charge', 'total intl charge']
# (2661, 13)
# ['total eve calls', 'total night charge', 'customer service calls']
# (2661, 13)
# ['total eve calls', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['total eve calls', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['total eve calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['total eve charge', 'total night calls', 'total night charge']
# (2661, 13)
# ['total eve charge', 'total night calls', 'total intl calls']
# (2661, 13)
# ['total eve charge', 'total night calls', 'total intl charge']
# (2661, 13)
# ['total eve charge', 'total night calls', 'customer service calls']
# (2661, 13)
# ['total eve charge', 'total night charge', 'total intl calls']
# (2661, 13)
# ['total eve charge', 'total night charge', 'total intl charge']
# (2661, 13)
# ['total eve charge', 'total night charge', 'customer service calls']
# (2661, 13)
# ['total eve charge', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['total eve charge', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['total eve charge', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['total night calls', 'total night charge', 'total intl calls']
# (2661, 13)
# ['total night calls', 'total night charge', 'total intl charge']
# (2661, 13)
# ['total night calls', 'total night charge', 'customer service calls']
# (2661, 13)
# ['total night calls', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['total night calls', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['total night calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['total night charge', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['total night charge', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['total night charge', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['total intl calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ********************************************            4
# ['account length', 'area code', 'international plan', 'number vmail messages']
# (2661, 13)
# 0.861607142857
# ['account length', 'area code', 'international plan', 'number vmail messages']
# ['account length', 'area code', 'international plan', 'total day calls']
# (2661, 13)
# ['account length', 'area code', 'international plan', 'total day charge']
# (2661, 13)
# ['account length', 'area code', 'international plan', 'total eve calls']
# (2661, 13)
# ['account length', 'area code', 'international plan', 'total eve charge']
# (2661, 13)
# ['account length', 'area code', 'international plan', 'total night calls']
# (2661, 13)
# ['account length', 'area code', 'international plan', 'total night charge']
# (2661, 13)
# ['account length', 'area code', 'international plan', 'total intl calls']
# (2661, 13)
# ['account length', 'area code', 'international plan', 'total intl charge']
# (2661, 13)
# ['account length', 'area code', 'international plan', 'customer service calls']
# (2661, 13)
# ['account length', 'area code', 'number vmail messages', 'total day calls']
# (2661, 13)
# ['account length', 'area code', 'number vmail messages', 'total day charge']
# (2661, 13)
# ['account length', 'area code', 'number vmail messages', 'total eve calls']
# (2661, 13)
# ['account length', 'area code', 'number vmail messages', 'total eve charge']
# (2661, 13)
# ['account length', 'area code', 'number vmail messages', 'total night calls']
# (2661, 13)
# ['account length', 'area code', 'number vmail messages', 'total night charge']
# (2661, 13)
# ['account length', 'area code', 'number vmail messages', 'total intl calls']
# (2661, 13)
# ['account length', 'area code', 'number vmail messages', 'total intl charge']
# (2661, 13)
# ['account length', 'area code', 'number vmail messages', 'customer service calls']
# (2661, 13)
# ['account length', 'area code', 'total day calls', 'total day charge']
# (2661, 13)
# ['account length', 'area code', 'total day calls', 'total eve calls']
# (2661, 13)
# ['account length', 'area code', 'total day calls', 'total eve charge']
# (2661, 13)
# ['account length', 'area code', 'total day calls', 'total night calls']
# (2661, 13)
# ['account length', 'area code', 'total day calls', 'total night charge']
# (2661, 13)
# ['account length', 'area code', 'total day calls', 'total intl calls']
# (2661, 13)
# ['account length', 'area code', 'total day calls', 'total intl charge']
# (2661, 13)
# ['account length', 'area code', 'total day calls', 'customer service calls']
# (2661, 13)
# ['account length', 'area code', 'total day charge', 'total eve calls']
# (2661, 13)
# ['account length', 'area code', 'total day charge', 'total eve charge']
# (2661, 13)
# ['account length', 'area code', 'total day charge', 'total night calls']
# (2661, 13)
# ['account length', 'area code', 'total day charge', 'total night charge']
# (2661, 13)
# ['account length', 'area code', 'total day charge', 'total intl calls']
# (2661, 13)
# ['account length', 'area code', 'total day charge', 'total intl charge']
# (2661, 13)
# ['account length', 'area code', 'total day charge', 'customer service calls']
# (2661, 13)
# ['account length', 'area code', 'total eve calls', 'total eve charge']
# (2661, 13)
# ['account length', 'area code', 'total eve calls', 'total night calls']
# (2661, 13)
# ['account length', 'area code', 'total eve calls', 'total night charge']
# (2661, 13)
# ['account length', 'area code', 'total eve calls', 'total intl calls']
# (2661, 13)
# ['account length', 'area code', 'total eve calls', 'total intl charge']
# (2661, 13)
# ['account length', 'area code', 'total eve calls', 'customer service calls']
# (2661, 13)
# ['account length', 'area code', 'total eve charge', 'total night calls']
# (2661, 13)
# ['account length', 'area code', 'total eve charge', 'total night charge']
# (2661, 13)
# ['account length', 'area code', 'total eve charge', 'total intl calls']
# (2661, 13)
# ['account length', 'area code', 'total eve charge', 'total intl charge']
# (2661, 13)
# ['account length', 'area code', 'total eve charge', 'customer service calls']
# (2661, 13)
# ['account length', 'area code', 'total night calls', 'total night charge']
# (2661, 13)
# ['account length', 'area code', 'total night calls', 'total intl calls']
# (2661, 13)
# ['account length', 'area code', 'total night calls', 'total intl charge']
# (2661, 13)
# ['account length', 'area code', 'total night calls', 'customer service calls']
# (2661, 13)
# ['account length', 'area code', 'total night charge', 'total intl calls']
# (2661, 13)
# ['account length', 'area code', 'total night charge', 'total intl charge']
# (2661, 13)
# ['account length', 'area code', 'total night charge', 'customer service calls']
# (2661, 13)
# ['account length', 'area code', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'area code', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'area code', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'number vmail messages', 'total day calls']
# (2661, 13)
# ['account length', 'international plan', 'number vmail messages', 'total day charge']
# (2661, 13)
# ['account length', 'international plan', 'number vmail messages', 'total eve calls']
# (2661, 13)
# ['account length', 'international plan', 'number vmail messages', 'total eve charge']
# (2661, 13)
# ['account length', 'international plan', 'number vmail messages', 'total night calls']
# (2661, 13)
# ['account length', 'international plan', 'number vmail messages', 'total night charge']
# (2661, 13)
# ['account length', 'international plan', 'number vmail messages', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'number vmail messages', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'number vmail messages', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total day charge']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total eve calls']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total eve charge']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total night calls']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total night charge']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve charge']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total night calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total night charge']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total eve charge']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total night calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total night charge']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve charge', 'total night calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve charge', 'total night charge']
# (2661, 13)
# ['account length', 'international plan', 'total eve charge', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve charge', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total eve charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total night calls', 'total night charge']
# (2661, 13)
# ['account length', 'international plan', 'total night calls', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total night calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total night calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total night charge', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total night charge', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total night charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total eve calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total eve charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total night calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total night charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total intl calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total intl charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'customer service calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day charge', 'total eve calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day charge', 'total eve charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day charge', 'total night calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day charge', 'total night charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day charge', 'total intl calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day charge', 'total intl charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day charge', 'customer service calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total eve calls', 'total eve charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total eve calls', 'total night calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total eve calls', 'total night charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total eve calls', 'total intl calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total eve calls', 'total intl charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total eve calls', 'customer service calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total eve charge', 'total night calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total eve charge', 'total night charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total eve charge', 'total intl calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total eve charge', 'total intl charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total eve charge', 'customer service calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total night calls', 'total night charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total night calls', 'total intl calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total night calls', 'total intl charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total night calls', 'customer service calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total night charge', 'total intl calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total night charge', 'total intl charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total night charge', 'customer service calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total day calls', 'total day charge', 'total eve calls']
# (2661, 13)
# ['account length', 'total day calls', 'total day charge', 'total eve charge']
# (2661, 13)
# ['account length', 'total day calls', 'total day charge', 'total night calls']
# (2661, 13)
# ['account length', 'total day calls', 'total day charge', 'total night charge']
# (2661, 13)
# ['account length', 'total day calls', 'total day charge', 'total intl calls']
# (2661, 13)
# ['account length', 'total day calls', 'total day charge', 'total intl charge']
# (2661, 13)
# ['account length', 'total day calls', 'total day charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total day calls', 'total eve calls', 'total eve charge']
# (2661, 13)
# ['account length', 'total day calls', 'total eve calls', 'total night calls']
# (2661, 13)
# ['account length', 'total day calls', 'total eve calls', 'total night charge']
# (2661, 13)
# ['account length', 'total day calls', 'total eve calls', 'total intl calls']
# (2661, 13)
# ['account length', 'total day calls', 'total eve calls', 'total intl charge']
# (2661, 13)
# ['account length', 'total day calls', 'total eve calls', 'customer service calls']
# (2661, 13)
# ['account length', 'total day calls', 'total eve charge', 'total night calls']
# (2661, 13)
# ['account length', 'total day calls', 'total eve charge', 'total night charge']
# (2661, 13)
# ['account length', 'total day calls', 'total eve charge', 'total intl calls']
# (2661, 13)
# ['account length', 'total day calls', 'total eve charge', 'total intl charge']
# (2661, 13)
# ['account length', 'total day calls', 'total eve charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total day calls', 'total night calls', 'total night charge']
# (2661, 13)
# ['account length', 'total day calls', 'total night calls', 'total intl calls']
# (2661, 13)
# ['account length', 'total day calls', 'total night calls', 'total intl charge']
# (2661, 13)
# ['account length', 'total day calls', 'total night calls', 'customer service calls']
# (2661, 13)
# ['account length', 'total day calls', 'total night charge', 'total intl calls']
# (2661, 13)
# ['account length', 'total day calls', 'total night charge', 'total intl charge']
# (2661, 13)
# ['account length', 'total day calls', 'total night charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total day calls', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'total day calls', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'total day calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total day charge', 'total eve calls', 'total eve charge']
# (2661, 13)
# ['account length', 'total day charge', 'total eve calls', 'total night calls']
# (2661, 13)
# ['account length', 'total day charge', 'total eve calls', 'total night charge']
# (2661, 13)
# ['account length', 'total day charge', 'total eve calls', 'total intl calls']
# (2661, 13)
# ['account length', 'total day charge', 'total eve calls', 'total intl charge']
# (2661, 13)
# ['account length', 'total day charge', 'total eve calls', 'customer service calls']
# (2661, 13)
# ['account length', 'total day charge', 'total eve charge', 'total night calls']
# (2661, 13)
# ['account length', 'total day charge', 'total eve charge', 'total night charge']
# (2661, 13)
# ['account length', 'total day charge', 'total eve charge', 'total intl calls']
# (2661, 13)
# ['account length', 'total day charge', 'total eve charge', 'total intl charge']
# (2661, 13)
# ['account length', 'total day charge', 'total eve charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total day charge', 'total night calls', 'total night charge']
# (2661, 13)
# ['account length', 'total day charge', 'total night calls', 'total intl calls']
# (2661, 13)
# ['account length', 'total day charge', 'total night calls', 'total intl charge']
# (2661, 13)
# ['account length', 'total day charge', 'total night calls', 'customer service calls']
# (2661, 13)
# ['account length', 'total day charge', 'total night charge', 'total intl calls']
# (2661, 13)
# ['account length', 'total day charge', 'total night charge', 'total intl charge']
# (2661, 13)
# ['account length', 'total day charge', 'total night charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total day charge', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'total day charge', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'total day charge', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total eve calls', 'total eve charge', 'total night calls']
# (2661, 13)
# ['account length', 'total eve calls', 'total eve charge', 'total night charge']
# (2661, 13)
# ['account length', 'total eve calls', 'total eve charge', 'total intl calls']
# (2661, 13)
# ['account length', 'total eve calls', 'total eve charge', 'total intl charge']
# (2661, 13)
# ['account length', 'total eve calls', 'total eve charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total eve calls', 'total night calls', 'total night charge']
# (2661, 13)
# ['account length', 'total eve calls', 'total night calls', 'total intl calls']
# (2661, 13)
# ['account length', 'total eve calls', 'total night calls', 'total intl charge']
# (2661, 13)
# ['account length', 'total eve calls', 'total night calls', 'customer service calls']
# (2661, 13)
# ['account length', 'total eve calls', 'total night charge', 'total intl calls']
# (2661, 13)
# ['account length', 'total eve calls', 'total night charge', 'total intl charge']
# (2661, 13)
# ['account length', 'total eve calls', 'total night charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total eve calls', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'total eve calls', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'total eve calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total eve charge', 'total night calls', 'total night charge']
# (2661, 13)
# ['account length', 'total eve charge', 'total night calls', 'total intl calls']
# (2661, 13)
# ['account length', 'total eve charge', 'total night calls', 'total intl charge']
# (2661, 13)
# ['account length', 'total eve charge', 'total night calls', 'customer service calls']
# (2661, 13)
# ['account length', 'total eve charge', 'total night charge', 'total intl calls']
# (2661, 13)
# ['account length', 'total eve charge', 'total night charge', 'total intl charge']
# (2661, 13)
# ['account length', 'total eve charge', 'total night charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total eve charge', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'total eve charge', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'total eve charge', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total night calls', 'total night charge', 'total intl calls']
# (2661, 13)
# ['account length', 'total night calls', 'total night charge', 'total intl charge']
# (2661, 13)
# ['account length', 'total night calls', 'total night charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total night calls', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'total night calls', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'total night calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total night charge', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'total night charge', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'total night charge', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'total intl calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['area code', 'international plan', 'number vmail messages', 'total day calls']
# (2661, 13)
# ['area code', 'international plan', 'number vmail messages', 'total day charge']
# (2661, 13)
# ['area code', 'international plan', 'number vmail messages', 'total eve calls']
# (2661, 13)
# ['area code', 'international plan', 'number vmail messages', 'total eve charge']
# (2661, 13)
# ['area code', 'international plan', 'number vmail messages', 'total night calls']
# (2661, 13)
# ['area code', 'international plan', 'number vmail messages', 'total night charge']
# (2661, 13)
# ['area code', 'international plan', 'number vmail messages', 'total intl calls']
# (2661, 13)
# ['area code', 'international plan', 'number vmail messages', 'total intl charge']
# (2661, 13)
# ['area code', 'international plan', 'number vmail messages', 'customer service calls']
# (2661, 13)
# ['area code', 'international plan', 'total day calls', 'total day charge']
# (2661, 13)
# ['area code', 'international plan', 'total day calls', 'total eve calls']
# (2661, 13)
# ['area code', 'international plan', 'total day calls', 'total eve charge']
# (2661, 13)
# ['area code', 'international plan', 'total day calls', 'total night calls']
# (2661, 13)
# ['area code', 'international plan', 'total day calls', 'total night charge']
# (2661, 13)
# ['area code', 'international plan', 'total day calls', 'total intl calls']
# (2661, 13)
# ['area code', 'international plan', 'total day calls', 'total intl charge']
# (2661, 13)
# ['area code', 'international plan', 'total day calls', 'customer service calls']
# (2661, 13)
# ['area code', 'international plan', 'total day charge', 'total eve calls']
# (2661, 13)
# ['area code', 'international plan', 'total day charge', 'total eve charge']
# (2661, 13)
# ['area code', 'international plan', 'total day charge', 'total night calls']
# (2661, 13)
# ['area code', 'international plan', 'total day charge', 'total night charge']
# (2661, 13)
# ['area code', 'international plan', 'total day charge', 'total intl calls']
# (2661, 13)
# ...
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total eve charge', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total night calls', 'total night charge', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total night calls', 'total night charge', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total night calls', 'total night charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total night calls', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total night calls', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total night calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total night charge', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total night charge', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total night charge', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day calls', 'total intl calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve calls', 'total eve charge', 'total night calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve calls', 'total eve charge', 'total night charge']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve calls', 'total eve charge', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve calls', 'total eve charge', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve calls', 'total eve charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve calls', 'total night calls', 'total night charge']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve calls', 'total night calls', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve calls', 'total night calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve calls', 'total night calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve calls', 'total night charge', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve calls', 'total night charge', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve calls', 'total night charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve calls', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve calls', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve charge', 'total night calls', 'total night charge']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve charge', 'total night calls', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve charge', 'total night calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve charge', 'total night calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve charge', 'total night charge', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve charge', 'total night charge', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve charge', 'total night charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve charge', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve charge', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total eve charge', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total night calls', 'total night charge', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total night calls', 'total night charge', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total night calls', 'total night charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total night calls', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total night calls', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total night calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total night charge', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total night charge', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total night charge', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total day charge', 'total intl calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total eve charge', 'total night calls', 'total night charge']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total eve charge', 'total night calls', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total eve charge', 'total night calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total eve charge', 'total night calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total eve charge', 'total night charge', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total eve charge', 'total night charge', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total eve charge', 'total night charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total eve charge', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total eve charge', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total eve charge', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total night calls', 'total night charge', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total night calls', 'total night charge', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total night calls', 'total night charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total night calls', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total night calls', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total night calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total night charge', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total night charge', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total night charge', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve calls', 'total intl calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve charge', 'total night calls', 'total night charge', 'total intl calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve charge', 'total night calls', 'total night charge', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total eve charge', 'total night calls', 'total night charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve charge', 'total night calls', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total eve charge', 'total night calls', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve charge', 'total night calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve charge', 'total night charge', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total eve charge', 'total night charge', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve charge', 'total night charge', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total eve charge', 'total intl calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total night calls', 'total night charge', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'international plan', 'total night calls', 'total night charge', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total night calls', 'total night charge', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total night calls', 'total intl calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'international plan', 'total night charge', 'total intl calls', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total eve calls', 'total eve charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total eve calls', 'total night calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total eve calls', 'total night charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total eve calls', 'total intl calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total eve calls', 'total intl charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total eve calls', 'customer service calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total eve charge', 'total night calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total eve charge', 'total night charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total eve charge', 'total intl calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total eve charge', 'total intl charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total eve charge', 'customer service calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total night calls', 'total night charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total night calls', 'total intl calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total night calls', 'total intl charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total night calls', 'customer service calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total night charge', 'total intl calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total night charge', 'total intl charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total night charge', 'customer service calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total intl calls', 'total intl charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total intl calls', 'customer service calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total day charge', 'total intl charge', 'customer service calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total eve calls', 'total eve charge', 'total night calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total eve calls', 'total eve charge', 'total night charge']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total eve calls', 'total eve charge', 'total intl calls']
# (2661, 13)
# ['account length', 'number vmail messages', 'total day calls', 'total eve calls', 'total eve charge', 'total intl charge']
# (2661, 13)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-9887f75cf6b1> in <module>()
#       9         ij_X_train, ij_y_train, ij_X_test, ij_y_test = get_data(col_names)
#      10         print(ij_X_train.shape)
# ---> 11         logreg         = LogisticRegression().fit(ij_X_train,ij_y_train)
#      12         ij_y_pred_test = logreg.predict(ij_X_test)
#      13         accuracy       = metrics.accuracy_score(ij_y_test, ij_y_pred_test)
#
# F:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1231                 self.class_weight, self.penalty, self.dual, self.verbose,
#    1232                 self.max_iter, self.tol, self.random_state,
# -> 1233                 sample_weight=sample_weight)
#    1234             self.n_iter_ = np.array([n_iter_])
#    1235             return self
#
# F:\Anaconda3\lib\site-packages\sklearn\svm\base.py in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     888         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     889         class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
# --> 890         epsilon, sample_weight)
#     891     # Regarding rnd.randint(..) in the above signature:
#     892     # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#
# KeyboardInterrupt:

# %%
X_train, y_train, X_test, y_test = get_data(list(df1_train.columns[:-1]))
logreg      = LogisticRegression().fit(X_train,y_train)
y_pred_test = logreg.predict(X_test)
metrics.accuracy_score(y_test, y_pred_test)
# Out:
# F:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:547: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8616071428571429
